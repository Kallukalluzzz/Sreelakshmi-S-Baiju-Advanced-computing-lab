# %% [markdown]
# <a href="https://colab.research.google.com/github/Kallukalluzzz/Sreelakshmi-S-Baiju-Advanced-computing-lab/blob/master/TSA_Dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/daily-total-female-births.csv',index_col='Date')
data
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %% [markdown]
# **PLOT THE DATA**

# %%
from matplotlib import pyplot
data.plot(figsize=(14,8))
pyplot.title("Daily temperature")
pyplot.show()

# %% [markdown]
# **PLOT HISTOGRAM**

# %%
data.hist()
pyplot.show()

# %% [markdown]
# **PLOT ACF**

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data)
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **PLOT PACF**

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data)
pyplot.show()

# %% [markdown]
# **STEPS FOR CHECKING STATIONARITY**

# %%
x = data.values
split = round(len(x) / 2)
x1, x2 = x[0:split], x[split:]
mean1, mean2 = x1.mean(), x2.mean()
var1, var2 = x1.var(), x2.var()

# %%
print(mean1, mean2)
# Out:
# 39.76373626373626 44.185792349726775

# %%
print(var1, var2)
# Out:
# 49.21341021615746 48.708650601690096
