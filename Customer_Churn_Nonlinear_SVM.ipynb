# %% [markdown]
# <a href="https://colab.research.google.com/github/Kallukalluzzz/gitproject/blob/master/Customer_Churn_Nonlinear_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("/telecom_churn.csv")

# %%
data.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %%
data.tail()
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 3328              2    156.2        77           71.7       10.78       9.9
# 3329              3    231.1        57           56.4        7.67       9.6
# 3330              2    180.8       109           56.0       14.44      14.1
# 3331              2    213.8       105           50.0        7.98       5.0
# 3332              0    234.4       113          100.0       13.30      13.7

# %%
X=data.drop(['Churn'],axis=1)
Y=data['Churn']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,train_size=0.5)

# %%
from sklearn.svm import SVC
svm=SVC(C=1.0,kernel="rbf")
svm=svm.fit(xtrain,ytrain)
res=svm.predict(xtest)
print(res)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(ytest,res)
print(score*100)
# Out:
# 85.48290341931613
