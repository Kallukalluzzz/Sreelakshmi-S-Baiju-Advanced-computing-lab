# %% [markdown]
# <a href="https://colab.research.google.com/github/Kallukalluzzz/gitproject/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("/telecom_churn.csv")

# %%
data.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %%
data.tail()
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 3328              2    156.2        77           71.7       10.78       9.9
# 3329              3    231.1        57           56.4        7.67       9.6
# 3330              2    180.8       109           56.0       14.44      14.1
# 3331              2    213.8       105           50.0        7.98       5.0
# 3332              0    234.4       113          100.0       13.30      13.7

# %%
X=data.drop(['Churn'],axis=1)
Y=data['Churn']

# %%
X
# Out:
#       AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0              128                1         1       2.70              1
# 1              107                1         1       3.70              1
# 2              137                1         0       0.00              0
# 3               84                0         0       0.00              2
# 4               75                0         0       0.00              3
# ...            ...              ...       ...        ...            ...
# 3328           192                1         1       2.67              2
# 3329            68                1         0       0.34              3
# 3330            28                1         0       0.00              2
# 3331           184                0         0       0.00              2
# 3332            74                1         1       3.70              0
#
#       DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear',C=1.0)
svm=svm.fit(X,Y)
res=svm.predict([[95,1,1,2.70,2,156.2,110,89.0,9.87,10.1]])
print(res)
# Out:
# [0]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"
