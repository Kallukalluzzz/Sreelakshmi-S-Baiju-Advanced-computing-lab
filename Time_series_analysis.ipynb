# %% [markdown]
# <a href="https://colab.research.google.com/github/Kallukalluzzz/Sreelakshmi-S-Baiju-Advanced-computing-lab/blob/master/Time_series_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/daily-min-temperatures.csv',index_col='Date')

# %%
data
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# **PLOT THE DATA**

# %%
from matplotlib import pyplot
data.plot(figsize=(14,8))
pyplot.title("Daily temperature")
pyplot.show()

# %% [markdown]
# **PLOT ACF**

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data)
pyplot.show()

# %% [markdown]
# **PLOT PACF**

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data)
pyplot.show()
