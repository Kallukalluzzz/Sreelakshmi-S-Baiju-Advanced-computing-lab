# %% [markdown]
# <a href="https://colab.research.google.com/github/Kallukalluzzz/Sreelakshmi-S-Baiju-Advanced-computing-lab/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/airline-passengers.csv',index_col='Month')
data
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %% [markdown]
# **PLOT THE DATA**

# %%
from matplotlib import pyplot
data.plot(figsize=(14,8))
pyplot.title("Daily temperature")
pyplot.show()

# %% [markdown]
# **PLOT HISTOGRAM**

# %%
data.hist()
pyplot.show()

# %% [markdown]
# **PLOT ACF**

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data)
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **PLOT PACF**

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data)
pyplot.show()

# %% [markdown]
# **STEPS FOR CHECKING STATIONARITY**

# %%
x = data.values
split = round(len(x) / 2)
x1, x2 = x[0:split], x[split:]
mean1, mean2 = x1.mean(), x2.mean()
var1, var2 = x1.var(), x2.var()

# %%
print(mean1, mean2)
# Out:
# 182.90277777777777 377.69444444444446

# %%
print(var1, var2)
# Out:
# 2244.0877700617284 7367.962191358024

# %% [markdown]
# **LOG TRANSFORM**

# %%
from numpy import log
x = data.values
x = log(x)
pyplot.hist(x)
pyplot.show()
pyplot.plot(x)
pyplot.show()

# %%
x = data.values
x = log(x)
split = round(len(x) / 2)
x1, x2 = x[0:split], x[split:]
mean1, mean2 = x1.mean(), x2.mean()
var1, var2 = x1.var(), x2.var()

# %%
print(mean1, mean2)
# Out:
# 5.17514614000377 5.909205777059973

# %%
print(var1, var2)
# Out:
# 0.06837486074542806 0.04926419375638024

# %% [markdown]
# **Test used to check stationary or non stationary**
